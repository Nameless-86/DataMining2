# %%
import pandas as pd

# %%
dataframe = pd.read_csv('coffee.csv')

# %%
dataframe.head()
# Out:
#    Data.Scores.Aroma  Data.Scores.Flavor  Data.Scores.Aftertaste  \
# 0               8.25                8.42                    8.08
# 1               8.17                7.92                    7.92
# 2               8.42                7.92                    8.00
# 3               7.67                8.00                    7.83
# 4               7.58                7.83                    7.58
#
#    Data.Scores.Acidity  Data.Scores.Body  Data.Scores.Balance  \
# 0                 7.75              7.67                 7.83
# 1                 7.75              8.33                 8.00
# 2                 7.75              7.92                 8.00
# 3                 8.00              7.92                 7.83
# 4                 8.00              7.83                 7.50
#
#    Data.Scores.Uniformity  Data.Scores.Sweetness  Data.Scores.Moisture  \
# 0                    10.0                   10.0                  0.00
# ...

# %%
dataframe = dataframe.drop(dataframe[dataframe['Data.Color'] == 'Unknown'].index)

# %%
dataframe = dataframe.dropna()

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 835 entries, 10 to 988
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Data.Scores.Aroma       835 non-null    float64
#  1   Data.Scores.Flavor      835 non-null    float64
#  2   Data.Scores.Aftertaste  835 non-null    float64
#  3   Data.Scores.Acidity     835 non-null    float64
#  4   Data.Scores.Body        835 non-null    float64
#  5   Data.Scores.Balance     835 non-null    float64
#  6   Data.Scores.Uniformity  835 non-null    float64
#  7   Data.Scores.Sweetness   835 non-null    float64
#  8   Data.Scores.Moisture    835 non-null    float64
#  9   Data.Scores.Total       835 non-null    float64
#  10  Data.Color              835 non-null    object
# dtypes: float64(10), object(1)
# memory usage: 78.3+ KB

# %%
dataframe.head()
# Out:
#     Data.Scores.Aroma  Data.Scores.Flavor  Data.Scores.Aftertaste  \
# 10               8.50                8.50                    8.00
# 11               8.50                8.17                    8.00
# 12               8.33                8.00                    8.00
# 13               8.00                8.00                    8.00
# 14               8.00                7.92                    7.75
#
#     Data.Scores.Acidity  Data.Scores.Body  Data.Scores.Balance  \
# 10                 8.00              8.00                 8.00
# 11                 7.75              8.00                 8.00
# 12                 8.00              7.75                 8.00
# 13                 7.67              7.75                 8.00
# 14                 7.75              8.00                 7.75
#
#     Data.Scores.Uniformity  Data.Scores.Sweetness  Data.Scores.Moisture  \
# 10                    10.0                   10.0                  0.12
# ...

# %%
guardar_limpio = dataframe.to_csv('cafe_limpio.csv', index=False)
